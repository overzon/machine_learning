# %%
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier
import numpy as np
iris = load_iris()
X = iris.data[:, 2:] # feature: petal length/width
y = iris.target # label: 0, 1, 2
np.random.seed(42)
tree_clf = DecisionTreeClassifier(max_depth=2,criterion='entropy')
tree_clf.fit(X, y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=2,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
from sklearn.tree import export_graphviz
tree_dot = export_graphviz(
    tree_clf,
    out_file=None, # or out_file="iris_tree.dot"
    feature_names=iris.feature_names[2:],
    class_names=iris.target_names,
    rounded=True,
    filled=True
)
print(tree_dot)
# Out:
# digraph Tree {
# node [shape=box, style="filled, rounded", color="black", fontname=helvetica] ;
# edge [fontname=helvetica] ;
# 0 [label="petal length (cm) <= 2.45\nentropy = 1.585\nsamples = 150\nvalue = [50, 50, 50]\nclass = setosa", fillcolor="#e5813900"] ;
# 1 [label="entropy = 0.0\nsamples = 50\nvalue = [50, 0, 0]\nclass = setosa", fillcolor="#e58139ff"] ;
# 0 -> 1 [labeldistance=2.5, labelangle=45, headlabel="True"] ;
# 2 [label="petal width (cm) <= 1.75\nentropy = 1.0\nsamples = 100\nvalue = [0, 50, 50]\nclass = versicolor", fillcolor="#39e58100"] ;
# 0 -> 2 [labeldistance=2.5, labelangle=-45, headlabel="False"] ;
# 3 [label="entropy = 0.445\nsamples = 54\nvalue = [0, 49, 5]\nclass = versicolor", fillcolor="#39e581e5"] ;
# 2 -> 3 ;
# 4 [label="entropy = 0.151\nsamples = 46\nvalue = [0, 1, 45]\nclass = virginica", fillcolor="#8139e5f9"] ;
# 2 -> 4 ;
# }

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
data = pd.read_csv('golf.csv')
oe = OneHotEncoder()
le = LabelEncoder
# oe.fit(data["Outlook"])


x = data[["Temperature","Humidity"]]
y = data["Play"]
np.random.seed(42)
tree_clf = DecisionTreeClassifier(max_depth=3)
tree_clf.fit(x, y)
from sklearn.tree import export_graphviz
tree_dot = export_graphviz(
    tree_clf,
    out_file=None, # or out_file="iris_tree.dot"
    feature_names=["Temperature","Humidity"],
    class_names=["yes","no"],
    rounded=True,
    filled=True
)
print(tree_dot)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-118-02b620585dfd> in <module>()
#       8 oe = OneHotEncoder()
#       9 le = LabelEncoder
# ---> 10 le.fit(data["Outlook"])
#      11
#      12
#
# TypeError: fit() missing 1 required positional argument: 'y'

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
data = pd.read_csv('golf.csv')
le = LabelEncoder()

LabelEncoder()
data["Outlook"] = le.fit_transform(data["Outlook"])
data["Wind"] = le.fit_transform(data["Wind"])
# list(le.classes_)
x = data[["Temperature","Humidity","Outlook","Wind"]]
y = data["Play"]
np.random.seed(42)
tree_clf = DecisionTreeClassifier(max_depth=3)
tree_clf.fit(x, y)
from sklearn.tree import export_graphviz
tree_dot = export_graphviz(
    tree_clf,
    out_file=None, # or out_file="iris_tree.dot"
    feature_names=["Temperature","Humidity"],
    class_names=["yes","no"],
    rounded=True,
    filled=True
)
print(tree_dot)
data
# Out:
#     Outlook  Temperature  Humidity  Wind Play
# 0         2           85        85     0   no
# 1         2           80        90     1   no
# 2         0           83        78     0  yes
# 3         1           70        96     0  yes
# 4         1           68        80     0  yes
# 5         1           65        70     1   no
# 6         0           64        65     1  yes
# 7         2           72        95     0   no
# 8         2           69        70     0  yes
# 9         1           75        80     0  yes
# 10        2           75        70     1  yes
# 11        0           72        90     1  yes
# 12        0           81        75     0  yes
# 13        1           71        80     1   no

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('golf.csv')
df = pd.concat([df,
                        pd.get_dummies(df['Outlook'], prefix='Outlook' , dummy_na=True)],axis=1).drop(['Outlook'],axis=1)
df = pd.concat([df,pd.get_dummies(df['Wind'],prefix='Wind',
                        dummy_na=True)],axis=1).drop(['Wind'],axis=1)

from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz
from sklearn.preprocessing import OneHotEncoder
x = df.drop(['Play'],axis=1)
y = df["Play"]
np.random.seed(42)
tree_clf = DecisionTreeClassifier(max_depth=3) #max_depth=2,criterion='entropy' เอาใ่ส่ใน()
tree_clf.fit(x, y)

tree_dot = export_graphviz(
    tree_clf,
    out_file=None, # or out_file="iris_tree.dot"
    feature_names=list(x),
    class_names=["yes","no"],
    rounded=True,
    filled=True
)
print(tree_dot)
# Out:
# digraph Tree {
# node [shape=box, style="filled, rounded", color="black", fontname=helvetica] ;
# edge [fontname=helvetica] ;
# 0 [label="Outlook_overcast <= 0.5\ngini = 0.459\nsamples = 14\nvalue = [5, 9]\nclass = no", fillcolor="#399de571"] ;
# 1 [label="Temperature <= 77.5\ngini = 0.5\nsamples = 10\nvalue = [5, 5]\nclass = yes", fillcolor="#e5813900"] ;
# 0 -> 1 [labeldistance=2.5, labelangle=45, headlabel="True"] ;
# 2 [label="Temperature <= 66.5\ngini = 0.469\nsamples = 8\nvalue = [3, 5]\nclass = no", fillcolor="#399de566"] ;
# 1 -> 2 ;
# 3 [label="gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = yes", fillcolor="#e58139ff"] ;
# 2 -> 3 ;
# 4 [label="gini = 0.408\nsamples = 7\nvalue = [2, 5]\nclass = no", fillcolor="#399de599"] ;
# 2 -> 4 ;
# 5 [label="gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = yes", fillcolor="#e58139ff"] ;
# 1 -> 5 ;
# 6 [label="gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = no", fillcolor="#399de5ff"] ;
# ...

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('golf.csv')
df = pd.concat([df,
                        pd.get_dummies(df['Outlook'], prefix='Outlook' , dummy_na=True)],axis=1).drop(['Outlook'],axis=1)

# %%
y
# Out:
# 0      no
# 1      no
# 2     yes
# 3     yes
# 4     yes
# 5      no
# 6     yes
# 7      no
# 8     yes
# 9     yes
# 10    yes
# 11    yes
# 12    yes
# 13     no
# Name: Play, dtype: object
