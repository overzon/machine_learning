# %%
from math import *
a = [0, pi/2, pi]
x = a[2]
if sin(x) == 0:
    print("zero")
elif sin(x) == 1:
    print("one")
else:
    print("huh")
# Out:
# huh

# %%
import numpy as np
a = np.array([[1,-1],[1,2]])
b = np.array([3,4])
print(a)
print(b)
print(a.dot(b))
# Out:
# [[ 1 -1]
#  [ 1  2]]
# [3 4]
# [-1 11]

# %%
import numpy as np
import matplotlib.pyplot as plt

n = 1000
x = np.arange(n)
y = np.random.rand(n)
plt.scatter(x,y)

# %%
for x in range(5,11):
    print (x)
# Out:
# 5
# 6
# 7
# 8
# 9
# 10

# %%
import numpy as np
import matplotlib.pyplot as plt

n = 10
x = range(n)
y = np.random.rand(n)
plt.scatter(x,y)
plt.plot(x,y)
# Out:
# range(0, 10)

# %%
x
# Out:
# range(0, 10)
